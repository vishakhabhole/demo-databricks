-- %%
%fs ls "abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/"

-- %%
SHOW CATALOGS;

-- %%
CREATE CATALOG bronze_catalog;

-- %%
CREATE CATALOG bronze_external_catalog
MANAGED LOCATION 'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/bronzeexternalLocation';

-- %%
SHOW CATALOGS;

-- %%
CREATE SCHEMA bronze_external_catalog.bronze_external_schema;

-- %%
USE CATALOG bronze_external_catalog;
SHOW SCHEMAS;

-- %%
--creates at external location 
CREATE SCHEMA bronze_external_catalog.bronze_ext_schema_1
MANAGED LOCATION 'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/bronzeexternalLocation/schema_1';

-- %%
CREATE TABLE bronze_external_catalog.bronze_ext_schema_1.bronze_ext_tbl(
    id INT,
    name STRING,
    salary double
)
using delta;

-- %%
%sql
--creates at external location table
create table bronze_external_catalog.bronze_ext_schema_1.bronze_ext_tbl_1(
    id int,
    name string
)
using delta location 'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/bronzeexternaldirectory/schema1/';

-- %%
show external locations;
