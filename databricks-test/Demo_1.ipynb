# %%
# %fs ls "abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/"

# %% [markdown]
# ####Insert Operation -- written things to table

# %%
# %sql
 CREATE CATALOG delta_catalog
 MANAGED LOCATION 'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/catalog'

# %%
# %sql
CREATE SCHEMA delta_catalog.demo_schema 
MANAGED LOCATION 'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/schema';

# %% [markdown]
# #### CTAS(create table as select)

# %%
# %sql
USE CATALOG delta_catalog;
CREATE TABLE demo_schema.customer_delta
USING DELTA
LOCATION 'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/customerDelta'
AS
SELECT 
  CAST(Customerid AS INT) AS customerid,
  Surname,
  CAST(Creditscore AS INT) AS creditscore,
  Geography,
  Gender,
  CAST(Age AS INT) AS age,
  CAST(Tenure AS INT) AS tenure,
  CAST(Balance AS DOUBLE) AS balance,
  CAST(Estimatedsalary AS DOUBLE) AS estimatedsalary
FROM read_files(
  'abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/bankchurn/bankchurn_1_50.csv',
  format => 'csv',
  header => 'true'
);

# %%
# %sql
DESCRIBE EXTENDED demo_schema.customer_delta

# %%
# %sql
select * from delta_catalog.demo_schema.customer_delta;

# %% [markdown]
# #### INSERT data into table

# %%
# %sql
INSERT INTO delta_catalog.demo_schema.customer_delta VALUES (1100051,'Barak',444,'France','Male',45,5,84350.07,243835.76)

# %%
# %sql
select * from delta_catalog.demo_schema.customer_delta where customerid = 1100051;

# %%
# %sql
UPDATE delta_catalog.demo_schema.customer_delta
SET age = 48
where customerid = 1100051;

# %%
# %sql
DELETE FROM delta_catalog.demo_schema.customer_delta WHERE customerid =1100051

# %%
# %sql
DESCRIBE HISTORY 
delta.`abfss://testdatabricksdemo@datbricksstrgaccextdl.dfs.core.windows.net/bronzeexternaldirectory/schema1`;
