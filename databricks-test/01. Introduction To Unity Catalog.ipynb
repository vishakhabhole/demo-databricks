# %%
####Check whether notebook is attached to Unity Catalog metastore

# %%
# %sql
SELECT current_metastore();

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql
DESCRIBE EXTERNAL LOCATION databricksdemo_tes_extloc;
