-- %%
%python
#***********************************************************************

-- %%
%python
#COMMANDS IN SQL

-- %%
DESCRIBE EXTENDED delta_catalog.demo_schema.customer_delta

-- %%
describe history delta_catalog.demo_schema.customer_delta

-- %%
SHOW CREATE TABLE demo_schema1.shallow_clonetable1
